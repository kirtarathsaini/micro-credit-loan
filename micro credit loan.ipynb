# %% [markdown]
# # MICRO CREDIT LOAN

# %%
#importing essential libraries that would be required.
import pandas as pd
import numpy as np

# %%
#reading the csv file and creating dataset in df variable
df=pd.read_csv('Data file.csv')

# %%
#this could helps to get the information about the data set in the variable named df.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
#this code tells the no of rows and columns present in the dataset.
df.shape
# Out:
# (209593, 37)

# %%
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
#this code tells the data type of the columns present in dataset.
df.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %%
#this code gives top five rows from the data
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
#this code give last 5 rows of the dataset.
#this code give last 5 rows of the dataset.
df.tail()
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 209588   1089.19   1089.19                1.0                0.0  ...
# 209589   1728.36   1728.36                4.0                0.0  ...
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
#this gives the sample row from the dataset
df.sample()
# Out:
#         Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 141671      141672      1  05092I88690  539.0   7936.786667        8045.9
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 141671    862.18    1276.1                1.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 141671              6.0                 0.0         14.0            84
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 141671                6                 0.0        4.5   4.461538      UPW
#
#              pdate
# 141671  2016-07-26
#
# [1 rows x 37 columns]

# %%
#this gives the column name from the dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# # CHECKING FOR THE DUPLICATED VALUES IN THE TABLE OR DATASET

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there are 0 duplicate values present in the data

# %% [markdown]
# # CHECKING FOR THE UNIQUE VALUES IN THE TABLE OR DATASET

# %% [markdown]
# # checking unique values in the whole dataset

# %%
df.nunique()
# Out:
# Unnamed: 0              209593
# label                        2
# msisdn                  186243
# aon                       4507
# daily_decr30            147025
# daily_decr90            158669
# rental30                132148
# rental90                141033
# last_rech_date_ma         1186
# last_rech_date_da         1174
# last_rech_amt_ma            70
# cnt_ma_rech30               71
# fr_ma_rech30              1083
# sumamnt_ma_rech30        15141
# medianamnt_ma_rech30       510
# medianmarechprebal30     30428
# cnt_ma_rech90              110
# fr_ma_rech90                89
# sumamnt_ma_rech90        31771
# medianamnt_ma_rech90       608
# medianmarechprebal90     29785
# cnt_da_rech30             1066
# fr_da_rech30              1072
# cnt_da_rech90               27
# fr_da_rech90                46
# cnt_loans30                 40
# amnt_loans30                48
# maxamnt_loans30           1050
# medianamnt_loans30           6
# cnt_loans90               1110
# ...

# %% [markdown]
# # checking unique values in the target variable

# %%
df['label'].nunique()
# Out:
# 2

# %% [markdown]
# # Checking for the Null Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
plt.title('Null Values')
# Out:
# Text(0.5, 1.0, 'Null Values')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# There are no null values present in the data set.

# %% [markdown]
# # EDA

# %% [markdown]
# # Visualization Of The Data

# %% [markdown]
# important libraries required for the visualization of the data has already been imported earlier.

# %% [markdown]
# # HISTOGRAM

# %%
df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# # VIOLINPLOT

# %%
sns.violinplot(df['daily_decr30'])
df['daily_decr30'].value_counts()
# Out:
# 0.000000        4144
# 500.000000       829
# 1000.000000      569
# 700.000000       381
# 600.000000       354
#                 ...
# 36.098000          1
# 75.915000          1
# 9.516667           1
# 21078.677000       1
# 4489.362000        1
# Name: daily_decr30, Length: 147025, dtype: int64

# %% [markdown]
# this graph tells Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
#
# most of them didn't spend the money and the mosr least spent amt is 4489.362000 by 1 person

# %%
sns.violinplot(df['daily_decr90'])
df['daily_decr90'].value_counts()
# Out:
# 0.000       4063
# 500.000      781
# 1000.000     490
# 700.000      343
# 600.000      316
#             ...
# 1282.220       1
# 1231.770       1
# 7385.270       1
# 91.425         1
# 4534.820       1
# Name: daily_decr90, Length: 158669, dtype: int64

# %% [markdown]
# this graph tells Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
#
#  most of the people 4063  Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah) is 0 and least number of people i.e 1  Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah) is 4534.820

# %%
sns.violinplot(df['rental30'])
df['rental30'].value_counts()
# Out:
# 0.00        7566
# 200.13      1379
# 99.56       1020
# 400.26       530
# 199.12       461
#             ...
# 11065.30       1
# 5234.44        1
# 948.71         1
# 296.75         1
# 483.92         1
# Name: rental30, Length: 132148, dtype: int64

# %% [markdown]
# this graph tells Average main account balance over last 30 days
#
# most of them had an average main acct balance acct balance of 0.00 over last 30 days around 7566 people and least of the avg main acct balance was 483.92

# %%
sns.violinplot(df['last_rech_date_ma'])
df['last_rech_date_ma'].value_counts()
# Out:
# 1.000000         47343
# 2.000000         26665
# 0.000000         20743
# 3.000000         19984
# 4.000000         15452
#                  ...
# 972385.270172        1
# 800187.053741        1
# 851900.041103        1
# 679670.490441        1
# 590843.121987        1
# Name: last_rech_date_ma, Length: 1186, dtype: int64

# %%
sns.violinplot(df['rental90'])
df['rental90'].value_counts()
# Out:
#  0.00        6918
#  200.13       913
#  99.56        767
#  60.00        691
#  90.00        685
#              ...
#  1278.64        1
#  2708.63        1
# -5.19           1
#  17733.55       1
#  984.58         1
# Name: rental90, Length: 141033, dtype: int64

# %% [markdown]
# this graph tells Average main account balance over last 90 days
#
# most of the users  Average main account balance over last 90 days is 0.0 and least number of people i.e 1 have  Average main account balance over last 90 days as 984.58

# %%
sns.violinplot(df['last_rech_amt_ma'])
df['last_rech_amt_ma'].value_counts()
# Out:
# 1539     56297
# 770      41766
# 0        20995
# 773      19523
# 2309     16113
#          ...
# 4066         1
# 15652        1
# 772          1
# 34783        1
# 10454        1
# Name: last_rech_amt_ma, Length: 70, dtype: int64

# %% [markdown]
# this graph tells Amount of last recharge of main account (in Indonesian Rupiah)
#
# most of the people 56297 have done 1539 Amount of last recharge of main account (in Indonesian Rupiah) and least number of people i.e 1 has done 10454 Amount of last recharge of main account (in Indonesian Rupiah)

# %%
sns.violinplot(df['cnt_ma_rech30'])
df['cnt_ma_rech30'].value_counts()
# Out:
# 1     37238
# 2     31216
# 0     27979
# 3     25519
# 4     20258
#       ...
# 84        1
# 59        1
# 64        1
# 74        1
# 63        1
# Name: cnt_ma_rech30, Length: 71, dtype: int64

# %% [markdown]
# this graph tells Number of times main account got recharged in last 30 days
#
# most of the people 37238 recharged main account 1 number of times in last 30 days and least number of people that recharged the account were 1 with number of recharges as 63 times the whole list is calculated above using essential codes of value count.

# %%
sns.violinplot(df['fr_ma_rech30'])
df['fr_ma_rech30'].value_counts()
# Out:
# 0.000000         78683
# 1.000000         22370
# 2.000000         18849
# 3.000000         14306
# 4.000000         11194
#                  ...
# 967338.131624        1
# 779697.846039        1
# 723333.519767        1
# 891246.004030        1
# 747564.075282        1
# Name: fr_ma_rech30, Length: 1083, dtype: int64

# %% [markdown]
# this graph tells the Frequency of main account recharged in last 30 days
#
# most of the people 78683 have 0 frequency of main account recharged in last 30 days and highest Frequency of main account recharged in last 30 days is 967338.131624 by 1 users

# %%
sns.violinplot(df['sumamnt_ma_rech30'])
df['sumamnt_ma_rech30'].value_counts()
# Out:
# 0.0        27979
# 1539.0      9006
# 770.0       6040
# 773.0       4540
# 2309.0      4509
#            ...
# 40924.0        1
# 38412.0        1
# 22899.0        1
# 5381.0         1
# 12154.0        1
# Name: sumamnt_ma_rech30, Length: 15141, dtype: int64

# %% [markdown]
# this graph tells Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)
#
# most of the people 27979 have done 0 Total amount of recharge in main account over last 30 days (in Indonesian Rupiah) and least number of people i.e 1 have done 12154.0 Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)

# %%
sns.violinplot(df['medianamnt_ma_rech30'])
df['medianamnt_ma_rech30'].value_counts()
# Out:
# 1539.0     47769
# 770.0      30754
# 0.0        27979
# 773.0      22680
# 2309.0     11177
#            ...
# 2690.5         1
# 4729.5         1
# 4742.0         1
# 3566.5         1
# 10963.5        1
# Name: medianamnt_ma_rech30, Length: 510, dtype: int64

# %% [markdown]
# this graph tells Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)
#
# most of the users 47769 have  Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah) as 1539.0 and least number of people with Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah) as 10963.5 is 1.

# %%
sns.violinplot(df['medianmarechprebal30'])
df['medianmarechprebal30'].value_counts()
# Out:
# 0.000000         30680
# 20.000000         1108
# 19.000000         1091
# 17.000000         1060
# 10.000000         1045
#                  ...
# 733852.248522        1
# 49.200000            1
# 70.810000            1
# 2051.000000          1
# 71.370000            1
# Name: medianmarechprebal30, Length: 30428, dtype: int64

# %% [markdown]
# this graph tells Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)
#
# most of the users 30680 have  Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah) as 0.0 and least number of people with Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah) as 71.370000 is 1.

# %%
sns.violinplot(df['cnt_ma_rech90'])
df['cnt_ma_rech90'].value_counts()
# Out:
# 1      27898
# 2      24052
# 0      20950
# 3      20446
# 4      17329
#        ...
# 105        1
# 110        1
# 140        1
# 94         1
# 120        1
# Name: cnt_ma_rech90, Length: 110, dtype: int64

# %% [markdown]
# this graph tells Number of times main account got recharged in last 90 days
#
# most of the people 27898 recharged main account 1 number of times in last 90 days and least number of people that recharged the account were 1 with number of recharges as 120 times the whole list is calculated above using essential codes of value count.

# %%
sns.violinplot(df['fr_ma_rech90'])
df['fr_ma_rech90'].value_counts()
# Out:
# 0     65753
# 1     24373
# 2     19285
# 3     13192
# 4     10021
#       ...
# 80        7
# 81        7
# 88        5
# 84        4
# 87        1
# Name: fr_ma_rech90, Length: 89, dtype: int64

# %% [markdown]
# this graph tells Frequency of main account recharged in last 90 days
#
# most of the people 65753 have 0 frequency of main account recharged in last 90 days and highest frequency of main account recharged in last 90 days is 88 by 5 users

# %%
sns.violinplot(df['sumamnt_ma_rech90'])
df['sumamnt_ma_rech90'].value_counts()
# Out:
# 0        20950
# 1539      5631
# 773       4177
# 770       3982
# 2309      2542
#          ...
# 32427        1
# 71229        1
# 78428        1
# 8241         1
# 17941        1
# Name: sumamnt_ma_rech90, Length: 31771, dtype: int64

# %% [markdown]
# this graph tells Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)
#
# most of the people 20950 have done 0 Total amount of recharge in main account over last 90 days (in Indonasian Rupiah) and least number of people i.e 1 have done 17941 Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)

# %%
sns.violinplot(df['medianamnt_ma_rech90'])
df['medianamnt_ma_rech90'].value_counts()
# Out:
# 1539.0     45780
# 773.0      30543
# 770.0      23844
# 0.0        20950
# 2309.0     10665
#            ...
# 8708.5         1
# 6350.0         1
# 4700.0         1
# 6818.0         1
# 10963.5        1
# Name: medianamnt_ma_rech90, Length: 608, dtype: int64

# %% [markdown]
# this graph tells the Median of amount of recharges done in main account over last 90 days at user level (in Indonasian Rupiah)
#
# most of the people 45780 have Median of amount of recharges done in main account over last 90 days at user level (in Indonasian Rupiah) of 1539.0 and least number of people i.e 1 have Median of amount of recharges done in main account over last 90 days at user level (in Indonasian Rupiah) as 10963.5

# %%
sns.violinplot(df['medianmarechprebal90'])
df['medianmarechprebal90'].value_counts()
# Out:
# 0.00      23391
# 20.00      1265
# 19.00      1208
# 26.00      1171
# 27.00      1166
#           ...
# 524.07        1
# 7.72          1
# 45.73         1
# 143.06        1
# 392.20        1
# Name: medianmarechprebal90, Length: 29785, dtype: int64

# %% [markdown]
# this account tells the Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)
#
# most of the people had median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah) as 0.0 and least number of people i.e 1 have Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah) as 392.20

# %%
sns.violinplot(df['cnt_da_rech30'])
df['cnt_da_rech30'].value_counts()
# Out:
# 0.000000        205479
# 1.000000          2331
# 2.000000           372
# 3.000000           156
# 4.000000            86
#                  ...
# 13710.643665         1
# 84844.562846         1
# 65385.403518         1
# 93840.663070         1
# 61002.421345         1
# Name: cnt_da_rech30, Length: 1066, dtype: int64

# %% [markdown]
# this graph tells the Number of times data account got recharged in last 30 days
#
# most of the people 205479 recharged account 0 number of times and least number of people that recharged the account were 1 with number of recharges as 61 times the whole list is calculated above using essential codes of value count.

# %%
sns.violinplot(df['fr_da_rech30'])
df['fr_da_rech30'].value_counts()
# Out:
# 0.000000         208014
# 3.000000             64
# 1.000000             55
# 2.000000             51
# 7.000000             47
#                   ...
# 757900.530472         1
# 870976.477512         1
# 797647.001920         1
# 519699.885393         1
# 509386.302670         1
# Name: fr_da_rech30, Length: 1072, dtype: int64

# %% [markdown]
# this graph tells Frequency of data account recharged in last 30 days
#
# most of the users frequency of data account recharged in last 30 days comes out to be 0 around 208014 people and the highest frequency of data account recharge in 30 days is done by only 1 frequency is 51 times the whole list is calculated above using value counts code.

# %%
sns.violinplot(df['cnt_da_rech90'])
df['cnt_da_rech90'].value_counts()
# Out:
# 0     204226
# 1       4173
# 2        556
# 3        227
# 4        150
# 5         74
# 6         49
# 7         36
# 8         30
# 9         18
# 14        10
# 12         7
# 11         7
# 13         6
# 10         6
# 16         4
# 18         3
# 15         2
# 20         1
# 25         1
# 28         1
# 30         1
# 22         1
# 38         1
# 19         1
# 27         1
# 17         1
# Name: cnt_da_rech90, dtype: int64

# %% [markdown]
#  this graph tells the Number of times data account got recharged in last 90 days
#
# most of the people 204226 recharged account 0 number of times and least number of people that recharged the account were 1 with number of recharges as 17
# the whole list is calculated above using essential codes of value count.

# %%
sns.violinplot(df['fr_da_rech90'])
df['fr_da_rech90'].value_counts()
# Out:
# 0     208728
# 3         78
# 1         66
# 2         66
# 4         56
# 7         55
# 6         52
# 5         45
# 8         44
# 10        33
# 14        32
# 9         32
# 11        30
# 12        27
# 19        22
# 28        19
# 15        17
# 13        17
# 18        16
# 29        15
# 16        14
# 17        14
# 25        11
# 22        11
# 21        10
# 20         9
# 32         8
# 24         8
# 27         8
# 26         7
# 30         7
# 31         6
# 34         5
# 37         5
# 23         5
# 57         3
# 35         2
# 41         2
# 42         1
# 39         1
# 33         1
# 43         1
# 56         1
# 46         1
# 55         1
# 64         1
# Name: fr_da_rech90, dtype: int64

# %% [markdown]
#  this graph tells the Frequency of data account recharged in last 90 days
#
# most of the users frequency of data account recharged in last 90 days comes out to be 0 around  208728 people and the highest frequency of data account recharge in 90 days is done by only 1 frequency is 64 times
# the whole list is calculated above using value counts code.

# %%
sns.violinplot(df['cnt_loans30'])
df['cnt_loans30'].value_counts()
# Out:
# 1     83432
# 2     42665
# 3     27050
# 4     17499
# 5     11673
# 6      7773
# 7      5041
# 8      3384
# 0      3259
# 9      2273
# 10     1571
# 11     1143
# 12      793
# 13      547
# 14      383
# 15      270
# 16      213
# 17      164
# 18       98
# 19       77
# 20       54
# 21       45
# 22       42
# 23       38
# 25       19
# 26       17
# 27       15
# 24       13
# 29        9
# 31        8
# 28        7
# 30        4
# 32        4
# 33        3
# 38        2
# 36        1
# 41        1
# 44        1
# 50        1
# 35        1
# Name: cnt_loans30, dtype: int64

# %% [markdown]
# this graph tells Number of loans taken by user in last 30 days
#
# most of the users took 1 loan around 83432 people and least number of people i.e 1 took 35 numbers of loan
#  the whole list is present above calculated using value counts code.

# %%
sns.violinplot(df['amnt_loans30'])
df['amnt_loans30'].value_counts()
# Out:
# 6      76620
# 12     44384
# 18     26379
# 24     18403
# 30     11999
# 36      8559
# 42      5580
# 48      3994
# 0       3259
# 54      2660
# 60      2043
# 66      1402
# 72      1101
# 78       742
# 84       580
# 90       394
# 96       333
# 102      252
# 108      182
# 114      135
# 120      119
# 132       92
# 126       80
# 138       64
# 156       34
# 150       30
# 144       30
# 162       29
# 168       20
# 174       17
# 186       15
# 180       13
# 192        7
# 198        6
# 252        4
# 210        4
# 228        4
# 216        4
# 222        3
# 258        3
# 264        3
# 276        3
# 240        2
# 204        2
# 246        1
# 300        1
# 270        1
# 306        1
# Name: amnt_loans30, dtype: int64

# %% [markdown]
# this graph tells the Total amount of loans taken by user in last 30 days
#
# most of the people took total amt of loan of 6 around 76620 users and the least number of people i.e 1 took total amount of loan of 306

# %%
sns.violinplot(df['maxamnt_loans30'])
df['maxamnt_loans30'].value_counts()
# Out:
# 6.000000        179193
# 12.000000        26109
# 0.000000          3244
# 17083.998141         1
# 62511.750702         1
#                  ...
# 30346.385852         1
# 66821.819056         1
# 55716.817238         1
# 41580.156627         1
# 96927.243252         1
# Name: maxamnt_loans30, Length: 1050, dtype: int64

# %% [markdown]
# this graph tells maximum amount of loan taken by the user in last 30 days
#
# most of the people around 179193 took loan of maximum amt of 6.000000 and least number of people that took loan of 96927.243252 amt is 1

# %%
sns.violinplot(df['medianamnt_loans30'])
df['medianamnt_loans30'].value_counts()
# Out:
# 0.0    195445
# 1.0      7149
# 0.5      6538
# 2.0       420
# 1.5        38
# 3.0         3
# Name: medianamnt_loans30, dtype: int64

# %% [markdown]
# this graph tells the Median of amounts of loan taken by the user in last 30 days
#
# mostly the median of amounts of loan taken by the users in last 30 days is 0.0 this is of 195445 people
#
# then followed by median of 1.0  for 7149 people
#
# then 0.5 for 6538 people
#
# then 2.0 for 420 people
#
# then 1.5 for 38 people
#
# then 3.0 for 3 people

# %%
sns.violinplot(df['cnt_loans90'])
df['cnt_loans30'].value_counts()
# Out:
# 1     83432
# 2     42665
# 3     27050
# 4     17499
# 5     11673
# 6      7773
# 7      5041
# 8      3384
# 0      3259
# 9      2273
# 10     1571
# 11     1143
# 12      793
# 13      547
# 14      383
# 15      270
# 16      213
# 17      164
# 18       98
# 19       77
# 20       54
# 21       45
# 22       42
# 23       38
# 25       19
# 26       17
# 27       15
# 24       13
# 29        9
# 31        8
# 28        7
# 30        4
# 32        4
# 33        3
# 38        2
# 36        1
# 41        1
# 44        1
# 50        1
# 35        1
# Name: cnt_loans30, dtype: int64

# %% [markdown]
# this graph tells the Number of loans taken by user in last 90 days
#
# most of the people around 83432 took only 1 loan and least no. of people took that is one took 35 numbers of loan

# %%
sns.violinplot(df['amnt_loans90'])
df['amnt_loans90'].value_counts()
# Out:
# 6      69131
# 12     38908
# 18     23867
# 24     17216
# 30     12503
#        ...
# 438        1
# 360        1
# 372        1
# 402        1
# 426        1
# Name: amnt_loans90, Length: 69, dtype: int64

# %% [markdown]
# this graph tells Total amount of loans taken by user in last 90 days
#
# most of them around 69131 people took total amount of loans of 6 then followed by 12 , 18 , 24, 30 and so on and the least individual that took total amount of loans of 426 amount is 1

# %%
sns.countplot(df['maxamnt_loans90'])
df['maxamnt_loans90'].value_counts()
# Out:
# 6     180945
# 12     26605
# 0       2043
# Name: maxamnt_loans90, dtype: int64

# %% [markdown]
# this graph tells maximum amount of loan taken by the user in last 90 days
#
# mostly people around 180945 took loan of maximum amt 6
#
# then 26605 people of maximum amt 12
#
# very few people didn't took loan around 2043

# %%
sns.violinplot(df['medianamnt_loans90'])
df['medianamnt_loans90'].value_counts()
# Out:
# 0.0    197424
# 1.0      6172
# 0.5      5668
# 2.0       307
# 1.5        19
# 3.0         3
# Name: medianamnt_loans90, dtype: int64

# %% [markdown]
# this graph tells the Median of amounts of loan taken by the user in last 90 days
#
# Median of amounts of loan taken by the user in last 90 days is 0.0 with taking most of the people into consideration around 197424 people and with leasr people into consideration the median is 3.0

# %%
sns.violinplot(df['payback30'])
df['payback30'].value_counts()
# Out:
# 0.000000     106712
# 2.000000       5601
# 3.000000       5023
# 4.000000       3931
# 2.500000       3518
#               ...
# 4.545455          1
# 48.400000         1
# 3.133333          1
# 1.518519          1
# 5.615385          1
# Name: payback30, Length: 1363, dtype: int64

# %% [markdown]
# this graph tells Average payback time in days over last 30 days
#
# average of most of the people payback time in days is is 0 around 106712 people and the most average no. of days took to pay back is around 6 days

# %%
sns.violinplot(df['payback90'])
df['payback90'].value_counts()
# Out:
# 0.000000     95699
# 2.000000      4982
# 3.000000      4437
# 4.000000      3610
# 2.500000      3015
#              ...
# 35.625000        1
# 48.400000        1
# 8.363636         1
# 62.666667        1
# 25.846154        1
# Name: payback90, Length: 2381, dtype: int64

# %% [markdown]
# this graph tells Average payback time in days over last 90 days
#
# average of most of the people payback time in days is is 0 around 95699 people and the most average no. of days took to pay back is around 26 days

# %%
sns.countplot(df['aon'])
df['aon'].value_counts()
# Out:
# 95.000000        392
# 92.000000        362
# 96.000000        357
# 99.000000        356
# 157.000000       349
#                 ...
# 977092.351997      1
# 645851.038396      1
# 881623.815396      1
# 555267.797667      1
# 811881.372822      1
# Name: aon, Length: 4507, dtype: int64

# %% [markdown]
# # countplot for target variable

# %%
sns.countplot(df['label'])
df['label'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# this graph tells whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
#
# 1    183431 people successfully paid
# 0     26162 people failed to pay

# %% [markdown]
# # Describing Data

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %%
df.describe(include='all')
# Out:
#            Unnamed: 0          label       msisdn            aon  \
# count   209593.000000  209593.000000       209593  209593.000000
# unique            NaN            NaN       186243            NaN
# top               NaN            NaN  04581I85330            NaN
# freq              NaN            NaN            7            NaN
# mean    104797.000000       0.875177          NaN    8112.343445
# std      60504.431823       0.330519          NaN   75696.082531
# min          1.000000       0.000000          NaN     -48.000000
# 25%      52399.000000       1.000000          NaN     246.000000
# 50%     104797.000000       1.000000          NaN     527.000000
# 75%     157195.000000       1.000000          NaN     982.000000
# max     209593.000000       1.000000          NaN  999860.755168
#
#          daily_decr30   daily_decr90       rental30       rental90  \
# count   209593.000000  209593.000000  209593.000000  209593.000000
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,14))
sns.heatmap(df.describe(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Encoding Data

# %% [markdown]
# # Encoding the categorical columns for furthe processing and model building

# %%
from sklearn import preprocessing

# %%
le= preprocessing.LabelEncoder()

# %%
df['msisdn']= le.fit_transform(df['msisdn'])

# %%
df['pcircle']= le.fit_transform(df['pcircle'])

# %%
df['pdate']= le.fit_transform(df['pdate'])

# %% [markdown]
# # Outliers Checking

# %%
collist=df.columns.values
ncol=30
nrow=14

# %%
collist
# Out:
# array(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30',
#        'daily_decr90', 'rental30', 'rental90', 'last_rech_date_ma',
#        'last_rech_date_da', 'last_rech_amt_ma', 'cnt_ma_rech30',
#        'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30',
#        'medianmarechprebal30', 'cnt_ma_rech90', 'fr_ma_rech90',
#        'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90',
#        'payback30', 'payback90', 'pcircle', 'pdate'], dtype=object)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# Unnamed: 0

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='blue',orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np

# %%
(np.abs(zscore(df))<3).all().all()
# Out:
# False

# %% [markdown]
# As the result is false so there are outliers present in the data set which will be treated afterwards.

# %% [markdown]
# # Checking correlation

# %%
df.corr()
# Out:
#                       Unnamed: 0     label    msisdn       aon  daily_decr30  \
# Unnamed: 0              1.000000  0.000403  0.000121 -0.002048      0.002739
# label                   0.000403  1.000000  0.001976 -0.003785      0.168298
# msisdn                  0.000121  0.001976  1.000000  0.000566      0.000717
# aon                    -0.002048 -0.003785  0.000566  1.000000      0.001104
# daily_decr30            0.002739  0.168298  0.000717  0.001104      1.000000
# daily_decr90            0.003077  0.166150  0.000950  0.000374      0.977704
# rental30               -0.003906  0.058085 -0.001404 -0.000960      0.442066
# rental90               -0.003459  0.075521 -0.000691 -0.000790      0.458977
# last_rech_date_ma      -0.001853  0.003728 -0.000928  0.001692      0.000487
# last_rech_date_da      -0.001133  0.001711  0.001400 -0.001693     -0.001636
# last_rech_amt_ma       -0.001064  0.131804 -0.002368  0.004256      0.275837
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking correlation of columns with the target variable

# %%
df.corr()['label'].sort_values()
# Out:
# fr_da_rech90           -0.005418
# medianmarechprebal30   -0.004829
# aon                    -0.003785
# fr_da_rech30           -0.000027
# maxamnt_loans30         0.000248
# Unnamed: 0              0.000403
# fr_ma_rech30            0.001330
# last_rech_date_da       0.001711
# msisdn                  0.001976
# cnt_da_rech90           0.002999
# last_rech_date_ma       0.003728
# cnt_da_rech30           0.003827
# cnt_loans90             0.004733
# medianamnt_loans90      0.035747
# medianmarechprebal90    0.039300
# medianamnt_loans30      0.044589
# payback30               0.048336
# payback90               0.049183
# rental30                0.058085
# rental90                0.075521
# maxamnt_loans90         0.084144
# fr_ma_rech90            0.084385
# medianamnt_ma_rech90    0.120855
# last_rech_amt_ma        0.131804
# medianamnt_ma_rech30    0.141490
# pdate                   0.162687
# daily_decr90            0.166150
# daily_decr30            0.168298
# ...

# %% [markdown]
# # checking the columns which are positively and negatively correlated to the target variable.

# %%
plt.figure(figsize=(12,10))
df.corr()['label'].sort_values(ascending=False).drop(['label']).plot(kind='bar',color='g')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# # Outliers Removing

# %% [markdown]
# zscore Technique

# %%
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64),
#  array([17, 17, 34, ..., 30, 28, 32], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, label, msisdn, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, pcircle, pdate]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_new.shape
# Out:
# (0, 37)

# %%
df.shape
# Out:
# (209593, 37)

# %%
data_loss=((209593-0)/209593)*100

# %%
data_loss
# Out:
# 100.0

# %% [markdown]
# This is the percentage of data lost

# %% [markdown]
# As the percentage loss is 100% there is no data no values left in the new dataset after removing outliers so there is no use of removing the outliers. we'll continue with the original dataset with the outliers.

# %% [markdown]
# seperating features and the target variable

# %%
features=df.drop('label',axis=1)
target=df['label']

# %%
features
# Out:
#         Unnamed: 0  msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0                1   40191   272.0   3055.050000   3065.150000    220.13
# 1                2  142291   712.0  12122.000000  12124.750000   3691.26
# 2                3   33594   535.0   1398.000000   1398.000000    900.13
# 3                4  104157   241.0     21.228000     21.228000    159.42
# 4                5    6910   947.0    150.619333    150.619333   1098.90
# ...            ...     ...     ...           ...           ...       ...
# 209588      209589   42866   404.0    151.872333    151.872333   1089.19
# 209589      209590  178248  1075.0     36.936000     36.936000   1728.36
# 209590      209591   53995  1013.0  11843.111667  11904.350000   5861.83
# 209591      209592  111388  1732.0  12488.228333  12574.370000    411.83
# 209592      209593  121263  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
target
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 209593, dtype: int64

# %% [markdown]
# checking skewness in Data and Removing it

# %%
features.skew()
# Out:
# Unnamed: 0               0.000000
# msisdn                   0.000719
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# ...

# %% [markdown]
# keeping -/+0.7 as the range of skewness. Here are the columns that are not in range.

# %%
from sklearn.preprocessing import power_transform

# %%
features.skew().sort_values(ascending=False)
# Out:
# medianmarechprebal90    44.880503
# fr_da_rech90            28.988083
# cnt_da_rech90           27.267278
# cnt_da_rech30           17.818364
# maxamnt_loans30         17.658052
# cnt_loans90             16.594408
# last_rech_date_da       14.814857
# last_rech_date_ma       14.790974
# medianmarechprebal30    14.779875
# fr_da_rech30            14.776430
# fr_ma_rech30            14.772833
# aon                     10.392949
# payback30                8.310695
# payback90                6.899951
# sumamnt_ma_rech30        6.386787
# sumamnt_ma_rech90        4.897950
# medianamnt_loans90       4.895720
# medianamnt_loans30       4.551043
# rental30                 4.521929
# rental90                 4.437681
# daily_decr90             4.252565
# daily_decr30             3.946230
# last_rech_amt_ma         3.781149
# medianamnt_ma_rech90     3.752706
# medianamnt_ma_rech30     3.512324
# cnt_ma_rech90            3.425254
# cnt_ma_rech30            3.283842
# ...

# %% [markdown]
# we are using YEO JOHNSON method

# %%
features_n=power_transform(features,method='yeo-johnson')

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# fr_da_rech90             15.469700
# fr_da_rech30             11.390665
# medianmarechprebal90      7.506286
# cnt_da_rech30             6.925820
# cnt_da_rech90             6.006577
# medianamnt_loans90        3.779598
# medianamnt_loans30        3.447735
# aon                       1.654517
# maxamnt_loans90           0.364282
# payback30                 0.298563
# payback90                 0.210887
# fr_ma_rech30              0.165015
# fr_ma_rech90              0.142952
# cnt_loans90               0.105580
# cnt_loans30               0.036243
# amnt_loans30              0.001948
# pcircle                   0.000000
# cnt_ma_rech30            -0.000145
# cnt_ma_rech90            -0.002465
# amnt_loans90             -0.008988
# medianamnt_ma_rech90     -0.044604
# last_rech_amt_ma         -0.061262
# medianmarechprebal30     -0.119058
# medianamnt_ma_rech30     -0.189628
# sumamnt_ma_rech90        -0.192158
# pdate                    -0.217699
# sumamnt_ma_rech30        -0.291322
# ...

# %%
type(features_n)
# Out:
# numpy.ndarray

# %%
features.columns
# Out:
# Index(['Unnamed: 0', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
features=pd.DataFrame(features_n,columns=features.columns)

# %%
features.skew().sort_values(ascending=False)
# Out:
# fr_da_rech90             15.469700
# fr_da_rech30             11.390665
# medianmarechprebal90      7.506286
# cnt_da_rech30             6.925820
# cnt_da_rech90             6.006577
# medianamnt_loans90        3.779598
# medianamnt_loans30        3.447735
# aon                       1.654517
# maxamnt_loans90           0.364282
# payback30                 0.298563
# payback90                 0.210887
# fr_ma_rech30              0.165015
# fr_ma_rech90              0.142952
# cnt_loans90               0.105580
# cnt_loans30               0.036243
# amnt_loans30              0.001948
# pcircle                   0.000000
# cnt_ma_rech30            -0.000145
# cnt_ma_rech90            -0.002465
# amnt_loans90             -0.008988
# medianamnt_ma_rech90     -0.044604
# last_rech_amt_ma         -0.061262
# medianmarechprebal30     -0.119058
# medianamnt_ma_rech30     -0.189628
# sumamnt_ma_rech90        -0.192158
# pdate                    -0.217699
# sumamnt_ma_rech30        -0.291322
# ...

# %% [markdown]
# skewness has been removed

# %% [markdown]
# # Training Process Begins

# %% [markdown]
# # Balancing The Data

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
fea_res,tar_res=sm.fit_resample(features,target)

# %%
fea_res.value_counts()
# Out:
# Unnamed: 0  msisdn     aon        daily_decr30  daily_decr90  rental30   rental90   last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  pdate
# ...

# %%
tar_res.value_counts()
# Out:
# 0    183431
# 1    183431
# Name: label, dtype: int64

# %% [markdown]
# # Finding Best Random State

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
maxaccu=0
maxRs=0
for i in range(0,200):
    fea_res_train,fea_res_test,tar_res_train,tar_res_test=train_test_split(fea_res,tar_res,test_size=.20,random_state=i)
    dt.fit(fea_res_train,tar_res_train)
    pre_train=dt.predict(fea_res_test)
    acc=accuracy_score(tar_res_test,pre_train)
    print('accuracy',acc,'random_state',i)
    
    if acc>maxaccu:
        maxaccu=acc
        maxRs=i
        print('maximum accuracy',maxaccu,'maximum random state',maxRs)
# Out:
# accuracy 0.9154457361699808 random_state 0
# maximum accuracy 0.9154457361699808 maximum random state 0
# accuracy 0.9132105815490712 random_state 1
# accuracy 0.9156229130606627 random_state 2
# maximum accuracy 0.9156229130606627 maximum random state 2
# accuracy 0.9152140433129353 random_state 3
# accuracy 0.9156910580186172 random_state 4
# maximum accuracy 0.9156910580186172 maximum random state 4
# accuracy 0.9165360554972538 random_state 5
# maximum accuracy 0.9165360554972538 maximum random state 5
# accuracy 0.9149278344895261 random_state 6
# accuracy 0.915254930287708 random_state 7
# accuracy 0.9151458983549807 random_state 8
# accuracy 0.9123519550788437 random_state 9
# accuracy 0.9162498466738446 random_state 10
# accuracy 0.9150368664222535 random_state 11
# accuracy 0.915868234909299 random_state 12
# accuracy 0.9184986302863452 random_state 13
# maximum accuracy 0.9184986302863452 maximum random state 13
# accuracy 0.9178171807067995 random_state 14
# ...

# %%
print('best accuracy score',maxaccu ,'on random state',maxRs)
# Out:
# best accuracy score 0.9194662886892999 on random state 172

# %% [markdown]
# # Create train test split

# %%
fea_res_train,fea_res_test,tar_res_train,tar_res_test=train_test_split(fea_res,tar_res,test_size=.20,random_state=172)

# %%
fea_res_train.shape
# Out:
# (293489, 36)

# %%
fea_res_test.shape
# Out:
# (73373, 36)

# %%
tar_res_train.shape
# Out:
# (293489,)

# %%
tar_res_test.shape
# Out:
# (73373,)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(fea_res_train,tar_res_train)
pre_train=dt.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 91.91664508742998
# [[34023  2733]
#  [ 3198 33419]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92     36756
#            1       0.92      0.91      0.92     36617
#
#     accuracy                           0.92     73373
#    macro avg       0.92      0.92      0.92     73373
# weighted avg       0.92      0.92      0.92     73373

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=300)
rf.fit(fea_res_train,tar_res_train)
pre_train=rf.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 95.5610374388399
# [[35314  1442]
#  [ 1815 34802]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     36756
#            1       0.96      0.95      0.96     36617
#
#     accuracy                           0.96     73373
#    macro avg       0.96      0.96      0.96     73373
# weighted avg       0.96      0.96      0.96     73373

# %% [markdown]
# # K Neighbors classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(fea_res_train,tar_res_train)
pre_train=knn.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 88.85421067695202
# [[36486   270]
#  [ 7908 28709]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90     36756
#            1       0.99      0.78      0.88     36617
#
#     accuracy                           0.89     73373
#    macro avg       0.91      0.89      0.89     73373
# weighted avg       0.91      0.89      0.89     73373

# %% [markdown]
# # cross validation score

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(dt,fea_res,tar_res,cv=9)
print('cross validation score for Decision tree model =', scr.mean())
# Out:
# cross validation score for Decision tree model = 0.830061855275453

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(rf,fea_res,tar_res,cv=9)
print('cross validation score for Random Forest Classifier  model =', scr.mean())
# Out:
# cross validation score for Random Forest Classifier  model = 0.8787884954086792

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(knn,fea_res,tar_res,cv=9)
print('cross validation score for K Neighbors classifiermodel =', scr.mean())
# Out:
# cross validation score for K Neighbors classifiermodel = 0.8579139840764978

# %% [markdown]
# # Random Forest Classifier is perfoming best among all the other models so we'll continue with it

# %% [markdown]
# # Hyper parameter tunning

# %% [markdown]
# # RandomForestClassifier()

# %%
#these are the parameters.
from sklearn.model_selection import GridSearchCV
parameters={'max_features':['auto','sqrt','log2'], 'max_depth':[4,5,6,7,8],'criterion':['ginni','entropy'],
           'n_estimators':[100,200,300,400,500]}

# %% [markdown]
# # after this jupyter wasn't giving any output it was just loading. I've tried everything in my hands that i know but i still have written the code .

# %% [markdown]
# # Using GridsearchCV

# %%
#usng gridsearch cv and random forest parameters.
gcv=GridSearchCV(RandomForestClassifier(),parameters,cv=9,scoring="accuracy")
gcv.fit(fea_res_train,tar_res_train)
gcv.best_params_

# %%
#finding the best estimator using grid search cv
gcv.best_estimator_

# %%
#predicting the best one now
gcv_pred=gcv.best_estimator_.predict(fea_res_test)
accuracy_score=(tar_res_test,gcv_pred)

# %%
#this is the accuracy score
accuracy_score

# %% [markdown]
# # ROC AUC curve

# %% [markdown]
# # Making ROC AUC Curve

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv.best_estimator_,fea_res_test,tar_res_test)
plt.title('ROC AUC plot')
plt.show

# %% [markdown]
# # SAVING THE MODEL

# %%
import joblib
joblib.dump(gcv.best_estimator_,'loan'.pkl')
